# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import requests

# https://www.kaggle.com/datasets/kritanjalijain/amazon-reviews
url = 'https://storage.googleapis.com/kaggle-data-sets/1340369/2233682/bundle/archive.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20241003%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20241003T115259Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...'
response = requests.get(url, stream=True)

save_path = '/content/drive/MyDrive/NLP Projects/Sentiment analysis/Dataset/archive.zip'

with open(save_path, 'wb') as file:
    for chunk in response.iter_content(chunk_size=1024):
        if chunk:
            file.write(chunk)

print("Download completed and saved to Google Drive.")
# Out:
# Download completed and saved to Google Drive.

# %%
import zipfile
import os

zip_file_name = save_path

extract_dir = "/content/drive/MyDrive/NLP Projects/Sentiment analysis/Dataset/"

with zipfile.ZipFile(zip_file_name, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)

print("Files successfully extracted!")
# Out:
# Files successfully extracted!
